# %% [markdown]
# ## Ablation testing notebook
#
# This notebook is meant to test different ablation values and magnitudes to determine what values are reasonable for inference.
#
# We will call the create-ablatio-data.py file on a small testing subset of COCO to test and visualize different values of motion blur and gaussian noise.
#
# 3 increasing values of each will be chosen to increase the difficulty of the task for the model
