# %% [markdown]
# Should take results from model-metrics.py for graphing and other testing in the form of a csv

# %% [markdown]
# Consider including WandB for logging and cloud saving.
#
# No manual required.

# %%
#imports

# %%
#inputs

"""
csv paths
model 1 
model 2
"""

# %%
#graphs and data analysis 

#basic stuff
#mean, var, etc of the scores

# %%
#graphs

CIDEr vs SPICE, compare relationships

Histograms of scores per model?

# %%
#image sampler
